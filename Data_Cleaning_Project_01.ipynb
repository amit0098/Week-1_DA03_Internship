# %% [markdown]
# # **Data Cleaning (Pandas)**

# %% [markdown]
# Importing Required Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing the Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/Data-cleaning-for-beginners-using-pandas.csv')

# %% [markdown]
# # **Data Pre Processing**

# %%
# checking first 5 rows of the Dataset
df.head()
# Out:
#    Index   Age     Salary  Rating       Location  Established Easy Apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
#Checking number of rows and columns
df.shape
# Out:
# (29, 7)

# %%
# getting some informations about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        29 non-null     int64
#  1   Age          22 non-null     float64
#  2   Salary       29 non-null     object
#  3   Rating       28 non-null     float64
#  4   Location     29 non-null     object
#  5   Established  29 non-null     int64
#  6   Easy Apply   29 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.7+ KB

# %%
df.describe()
# Out:
#            Index        Age     Rating  Established
# count  29.000000  22.000000  28.000000    29.000000
# mean   14.000000  39.045455   3.528571  1638.620690
# std     8.514693  16.134781   2.825133   762.079599
# min     0.000000  13.000000  -1.000000    -1.000000
# 25%     7.000000  25.000000   1.050000  1935.000000
# 50%    14.000000  39.500000   4.200000  1984.000000
# 75%    21.000000  50.000000   5.400000  1999.000000
# max    28.000000  66.000000   7.800000  2020.000000

# %%
# check the number of missing values in each column
df.isnull().sum()
# Out:
# Index          0
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# Index           0.000000
# Age            24.137931
# Salary          0.000000
# Rating          3.448276
# Location        0.000000
# Established     0.000000
# Easy Apply      0.000000
# dtype: float64

# %% [markdown]
# # **Handling Missing Values**

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.head(29)
# Out:
#     Index        Age      Salary  Rating       Location  Established  \
# 0       0  44.000000   $44k-$99k     5.4       India,In         1999
# 1       1  66.000000   $55k-$66k     3.5    New York,Ny         2002
# 2       2  39.045455   $77k-$89k    -1.0    New York,Ny           -1
# 3       3  64.000000   $44k-$99k     4.4       India In         1988
# 4       4  25.000000   $44k-$99k     6.4  Australia Aus         2002
# 5       5  44.000000   $77k-$89k     1.4       India,In         1999
# 6       6  21.000000   $44k-$99k     0.0    New York,Ny           -1
# 7       7  44.000000   $44k-$99k    -1.0  Australia Aus           -1
# 8       8  35.000000   $44k-$99k     5.4    New York,Ny           -1
# 9       9  22.000000   $44k-$99k     7.7       India,In           -1
# 10     10  55.000000   $10k-$49k     5.4       India,In         2008
# 11     11  44.000000   $10k-$49k     6.7       India,In         2009
# 12     12  39.045455   $44k-$99k     0.0       India,In         1999
# 13     13  25.000000   $44k-$99k    -1.0  Australia Aus         2019
# 14     14  66.000000   $44k-$99k     4.0  Australia Aus         2020
# 15     15  44.000000  $88k-$101k     3.0  Australia Aus         1999
# 16     16  19.000000   $19k-$40k     4.5       India,In         1984
# 17     17  39.045455   $44k-$99k     5.3    New York,Ny         1943
# 18     18  35.000000   $44k-$99k     6.7    New York,Ny         1954
# 19     19  32.000000   $44k-$99k     3.3    New York,Ny         1955
# 20     20  39.045455   $44k-$99k     5.7    New York,Ny         1944
# 21     21  35.000000   $44k-$99k     5.0    New York,Ny         1946
# 22     22  19.000000   $55k-$66k     7.8    New York,Ny         1988
# 23     23  39.045455   $44k-$99k     2.4    New York,Ny         1999
# 24     24  13.000000   $44k-$99k    -1.0    New York,Ny         1987
# 25     25  55.000000   $44k-$99k     0.0  Australia Aus         1980
# 26     26  39.045455   $55k-$66k     NaN       India,In         1934
# 27     27  52.000000   $44k-$99k     5.4       India,In         1935
# 28     28  39.045455   $39k-$88k     3.4  Australia Aus         1932
#
#    Easy Apply
# 0        TRUE
# 1        TRUE
# 2          -1
# 3          -1
# 4          -1
# 5        TRUE
# 6          -1
# 7          -1
# 8          -1
# 9        TRUE
# 10       TRUE
# 11         -1
# 12         -1
# 13       TRUE
# 14       TRUE
# 15         -1
# 16         -1
# 17       TRUE
# 18       TRUE
# 19       TRUE
# 20       TRUE
# 21         -1
# 22       TRUE
# 23       TRUE
# 24         -1
# 25       TRUE
# 26       TRUE
# 27         -1
# 28         -1

# %%
df.isnull().sum()
# Out:
# Index          0
# Age            0
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
# Correcting the Rating column
# Replace negative values with NaN
df['Rating'] = df['Rating'].apply(lambda x: np.nan if x < 0 else x)

# %%
# Handling NaN values (e.g., using mean imputation)
rating_mean = df['Rating'].mean()
df['Rating'].fillna(rating_mean, inplace=True)

# %% [markdown]
# Correcting the Established column

# %%
# Replace -1 values with NaN
df['Established'] = df['Established'].replace(-1, np.nan)

# %%
established_median = df['Established'].median()
df['Established'].fillna(established_median, inplace=True)

# %%
# Correcting the Easy Apply column
# Replace -1 with False and TRUE with True
df['Easy Apply'] = df['Easy Apply'].replace('-1', 'False').replace('TRUE', 'True')

# %%
df.isnull().sum()
# Out:
# Index          0
# Age            0
# Salary         0
# Rating         0
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %% [markdown]
# We will Remove Special Character in Salary Columns ,Remove dollar signs and 'k' characters to convert the salary ranges to numerical values.
#
# And Split the Salary Range.

# %%
# Function to clean and split the salary column
def process_salary(salary):
    salary = salary.replace('$', '').replace('k', '').split('-')
    min_salary = int(salary[0]) * 1000
    max_salary = int(salary[1]) * 1000 if len(salary) > 1 else min_salary
    return min_salary, max_salary

# Apply the function to the Salary column and create new columns
df[['Min_Salary', 'Max_Salary']] = df['Salary'].apply(lambda x: pd.Series(process_salary(x)))
df['Avg_Salary'] = df[['Min_Salary', 'Max_Salary']].mean(axis=1)

# %%
df.head(29)
# Out:
#     Index        Age      Salary    Rating       Location  Established  \
# 0       0  44.000000   $44k-$99k  5.400000       India,In       1999.0
# 1       1  66.000000   $55k-$66k  3.500000    New York,Ny       2002.0
# 2       2  39.045455   $77k-$89k  4.283333    New York,Ny       1988.0
# 3       3  64.000000   $44k-$99k  4.400000       India In       1988.0
# 4       4  25.000000   $44k-$99k  6.400000  Australia Aus       2002.0
# 5       5  44.000000   $77k-$89k  1.400000       India,In       1999.0
# 6       6  21.000000   $44k-$99k  0.000000    New York,Ny       1988.0
# 7       7  44.000000   $44k-$99k  4.283333  Australia Aus       1988.0
# 8       8  35.000000   $44k-$99k  5.400000    New York,Ny       1988.0
# 9       9  22.000000   $44k-$99k  7.700000       India,In       1988.0
# 10     10  55.000000   $10k-$49k  5.400000       India,In       2008.0
# 11     11  44.000000   $10k-$49k  6.700000       India,In       2009.0
# 12     12  39.045455   $44k-$99k  0.000000       India,In       1999.0
# 13     13  25.000000   $44k-$99k  4.283333  Australia Aus       2019.0
# 14     14  66.000000   $44k-$99k  4.000000  Australia Aus       2020.0
# 15     15  44.000000  $88k-$101k  3.000000  Australia Aus       1999.0
# 16     16  19.000000   $19k-$40k  4.500000       India,In       1984.0
# 17     17  39.045455   $44k-$99k  5.300000    New York,Ny       1943.0
# 18     18  35.000000   $44k-$99k  6.700000    New York,Ny       1954.0
# 19     19  32.000000   $44k-$99k  3.300000    New York,Ny       1955.0
# 20     20  39.045455   $44k-$99k  5.700000    New York,Ny       1944.0
# 21     21  35.000000   $44k-$99k  5.000000    New York,Ny       1946.0
# 22     22  19.000000   $55k-$66k  7.800000    New York,Ny       1988.0
# 23     23  39.045455   $44k-$99k  2.400000    New York,Ny       1999.0
# 24     24  13.000000   $44k-$99k  4.283333    New York,Ny       1987.0
# 25     25  55.000000   $44k-$99k  0.000000  Australia Aus       1980.0
# 26     26  39.045455   $55k-$66k  4.283333       India,In       1934.0
# 27     27  52.000000   $44k-$99k  5.400000       India,In       1935.0
# 28     28  39.045455   $39k-$88k  3.400000  Australia Aus       1932.0
#
#    Easy Apply  Min_Salary  Max_Salary  Avg_Salary
# 0        True       44000       99000     71500.0
# 1        True       55000       66000     60500.0
# 2       False       77000       89000     83000.0
# 3       False       44000       99000     71500.0
# 4       False       44000       99000     71500.0
# 5        True       77000       89000     83000.0
# 6       False       44000       99000     71500.0
# 7       False       44000       99000     71500.0
# 8       False       44000       99000     71500.0
# 9        True       44000       99000     71500.0
# 10       True       10000       49000     29500.0
# 11      False       10000       49000     29500.0
# 12      False       44000       99000     71500.0
# 13       True       44000       99000     71500.0
# 14       True       44000       99000     71500.0
# 15      False       88000      101000     94500.0
# 16      False       19000       40000     29500.0
# 17       True       44000       99000     71500.0
# 18       True       44000       99000     71500.0
# 19       True       44000       99000     71500.0
# 20       True       44000       99000     71500.0
# 21      False       44000       99000     71500.0
# 22       True       55000       66000     60500.0
# 23       True       44000       99000     71500.0
# 24      False       44000       99000     71500.0
# 25       True       44000       99000     71500.0
# 26       True       55000       66000     60500.0
# 27      False       44000       99000     71500.0
# 28      False       39000       88000     63500.0

# %%
# Removing unnecessary decimal places
df['Age'] = df['Age'].round(0).astype(int)
df['Rating'] = df['Rating'].round(1)
df['Established'] = df['Established'].round(0).astype(int)

# %%
df.head(29)
# Out:
#     Index  Age      Salary  Rating       Location  Established Easy Apply  \
# 0       0   44   $44k-$99k     5.4       India,In         1999       True
# 1       1   66   $55k-$66k     3.5    New York,Ny         2002       True
# 2       2   39   $77k-$89k     4.3    New York,Ny         1988      False
# 3       3   64   $44k-$99k     4.4       India In         1988      False
# 4       4   25   $44k-$99k     6.4  Australia Aus         2002      False
# 5       5   44   $77k-$89k     1.4       India,In         1999       True
# 6       6   21   $44k-$99k     0.0    New York,Ny         1988      False
# 7       7   44   $44k-$99k     4.3  Australia Aus         1988      False
# 8       8   35   $44k-$99k     5.4    New York,Ny         1988      False
# 9       9   22   $44k-$99k     7.7       India,In         1988       True
# 10     10   55   $10k-$49k     5.4       India,In         2008       True
# 11     11   44   $10k-$49k     6.7       India,In         2009      False
# 12     12   39   $44k-$99k     0.0       India,In         1999      False
# 13     13   25   $44k-$99k     4.3  Australia Aus         2019       True
# 14     14   66   $44k-$99k     4.0  Australia Aus         2020       True
# 15     15   44  $88k-$101k     3.0  Australia Aus         1999      False
# 16     16   19   $19k-$40k     4.5       India,In         1984      False
# 17     17   39   $44k-$99k     5.3    New York,Ny         1943       True
# 18     18   35   $44k-$99k     6.7    New York,Ny         1954       True
# 19     19   32   $44k-$99k     3.3    New York,Ny         1955       True
# 20     20   39   $44k-$99k     5.7    New York,Ny         1944       True
# 21     21   35   $44k-$99k     5.0    New York,Ny         1946      False
# 22     22   19   $55k-$66k     7.8    New York,Ny         1988       True
# 23     23   39   $44k-$99k     2.4    New York,Ny         1999       True
# 24     24   13   $44k-$99k     4.3    New York,Ny         1987      False
# 25     25   55   $44k-$99k     0.0  Australia Aus         1980       True
# 26     26   39   $55k-$66k     4.3       India,In         1934       True
# 27     27   52   $44k-$99k     5.4       India,In         1935      False
# 28     28   39   $39k-$88k     3.4  Australia Aus         1932      False
#
#     Min_Salary  Max_Salary  Avg_Salary
# 0        44000       99000     71500.0
# 1        55000       66000     60500.0
# 2        77000       89000     83000.0
# 3        44000       99000     71500.0
# 4        44000       99000     71500.0
# 5        77000       89000     83000.0
# 6        44000       99000     71500.0
# 7        44000       99000     71500.0
# 8        44000       99000     71500.0
# 9        44000       99000     71500.0
# 10       10000       49000     29500.0
# 11       10000       49000     29500.0
# 12       44000       99000     71500.0
# 13       44000       99000     71500.0
# 14       44000       99000     71500.0
# 15       88000      101000     94500.0
# 16       19000       40000     29500.0
# 17       44000       99000     71500.0
# 18       44000       99000     71500.0
# 19       44000       99000     71500.0
# 20       44000       99000     71500.0
# 21       44000       99000     71500.0
# 22       55000       66000     60500.0
# 23       44000       99000     71500.0
# 24       44000       99000     71500.0
# 25       44000       99000     71500.0
# 26       55000       66000     60500.0
# 27       44000       99000     71500.0
# 28       39000       88000     63500.0
